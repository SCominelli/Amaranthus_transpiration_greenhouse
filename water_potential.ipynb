# %%
import pandas as pd
import numpy as np
import time

# %%
theta = 0.2

#The following values are obtained fro the curve fitting (theta_r, theta_s, n, m and alpha)

theta_r = 0.0881
theta_s = 0.5128
n = 1.626
m = 0.2047
alpha = 0.5813

theta_relative = (theta - theta_r)/(theta_s - theta_r)
psi = (((((theta_relative**(1/-m)))-1) **(1/n)))* (-1/alpha)

print(psi)
# Out:
# -94.52024061213992

# %%
df = pd.read_excel ('C:/Users/scominelli/Soil Water Lab Dropbox/Sofia Cominelli/Sofia Cominelli/Projects/Amaranthus_transpiration\data/volumetric_water.xlsx')
df.interpolate()
df.head()
# Out:
#             timestamp  theta_s  theta_r   alpha      n       m  \
# 0 2021-05-01 00:00:00   0.0881   0.5128  0.5813  1.626  0.2047
# 1 2021-05-01 01:00:00   0.0881   0.5128  0.5813  1.626  0.2047
# 2 2021-05-01 02:00:00   0.0881   0.5128  0.5813  1.626  0.2047
# 3 2021-05-01 03:00:00   0.0881   0.5128  0.5813  1.626  0.2047
# 4 2021-05-01 04:00:00   0.0881   0.5128  0.5813  1.626  0.2047
#
#    volumetric_water_y  volumetric_water_w  volumetric_water_u  \
# 0            0.180382            0.174448            0.210319
# 1            0.180045            0.174111            0.210319
# 2            0.180045            0.173774            0.209982
# 3            0.180045            0.173774            0.209644
# 4            0.180045            0.173437            0.209644
#
#    volumetric_water_s  volumetric_water_q  volumetric_water_o  Unnamed: 12  \
# 0            0.174979                 NaN            0.167237          NaN
# ...

# %%
#I want to quit the colimns unnamed because they do not have values

#Used the equation to try the volumetric water content for the days that plants were suppoused to entered in stress conditions (between 18 and 22 of May) in order to obtain the water potencial

# %%
thetav = 0.13

theta_res = 0.0881
theta_sat = 0.5128
alpha = 0.5813
n = 1.626
m = 0.2047
theta_relative = (0.14 - theta_res)/(theta_sat - theta_res)
psi = (((((theta_relative**(1/-m)))-1)**(1/n))) * (-1/alpha)

print (psi)
# Out:
# -951.4289042246845
